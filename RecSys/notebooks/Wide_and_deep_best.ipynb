# %%
## DO NOT ERASE THIS. IMPORTANT TO CORRECTLY IMPORT MODULES
import sys

sys.path.append("../")
sys.executable
# Out:
# '/Users/kristina/Desktop/University/COURSE_WORK/RecSys_thesis/recsysvenv/bin/python3.12'

# %%
import pandas as pd

pd.set_option("display.max_rows", 102)

from tqdm.auto import tqdm
import mmh3

import torch
from torch.utils.data import DataLoader, TensorDataset

from src.utils import (
    load_MovieLens,
    create_test_user,
    train_test_val_split,
    seed_everything,
    trainDatasetWithCrossFeatures,
    split_test_df,
    add_not_watched_movies,
    create_test_user_display_df,
    train,
    predict,
)
from src.models import wideAndDeep
from src.metrics import reccomendation_report

# %% [markdown]
# ## Constants

# %%
DATA_FOLDER = "../../data/ml-1m/"
RANDOM_STATE = 7

# %%
seed_everything(RANDOM_STATE)

# %% [markdown]
# ## Data

# %%
df_users, df_movies, df_ratings = load_MovieLens(DATA_FOLDER)

# %% [markdown]
# ### Creating a test_user

# %%
df_users, df_ratings, new_user_id = create_test_user(
    df_users, df_ratings, [6, 16, 3192, 1461, 827, 887, 593]
)
print("Test user watch list:")
display(df_ratings[df_ratings.userId == new_user_id].merge(df_movies, on="movieId"))
# Out:
# Test user watch list:
#    userId  movieId  rating  timestamp                                name  \
# 0    6040        6       5          0                      Sabrina (1995)
# 1    6040       16       5          1        Sense and Sensibility (1995)
# 2    6040     3192       5          2                      Singles (1992)
# 3    6040     1461       5          3  Love and Other Catastrophes (1996)
# 4    6040      827       5          4                         Emma (1996)
# 5    6040      887       5          5          Singin' in the Rain (1952)
# 6    6040      593       5          6                 Pretty Woman (1990)
#
#                   genre
# 0        Comedy|Romance
# 1         Drama|Romance
# 2  Comedy|Drama|Romance
# 3               Romance
# 4  Comedy|Drama|Romance
# 5       Musical|Romance
# 6        Comedy|Romance

# %% [markdown]
# ### Train-test split
# Methodology: Last user interaction is a test item. The rest is train. Validation part is 20% of test.

# %%
df_train, df_test, df_val = train_test_val_split(df_ratings, df_movies, RANDOM_STATE)
# Out:
# Enriching test:   0%|          | 0/4832 [00:00<?, ?it/s]
# Enriching val:   0%|          | 0/1209 [00:00<?, ?it/s]

# %% [markdown]
# ### Loading additional data

# %%
# cos_dist = computeCosineSimilarities(df_train, "userId", "movieId", df_movies["movieId"].nunique())

# with open("../../data/cos_dist.pt", "wb") as f:
#     torch.save(cos_dist, f)

with open("../../data/cos_dist.pt", "rb") as f:
    cos_dist = torch.load(f)
popularity = torch.bincount(
    torch.tensor(df_train.movieId.values), minlength=df_movies["movieId"].nunique()
)
popularity = popularity / torch.max(popularity)

# %% [markdown]
# ### Building cross features

# %%
cross_feats_dim = 30
df_users["combined_feat"] = (
    df_users["gender"].astype(str)
    + df_users["age"].astype(str)
    + df_users["occupation"].astype(str)
)
user_features_mapping = {
    i: df_users.loc[df_users.userId == i, "combined_feat"].values[0]
    for i in df_users.userId.unique()
}
movie_features_mapping = {
    i: df_movies.loc[df_movies.movieId == i, "genre"].values[0]
    for i in df_movies.movieId.unique()
}


# cross features for test
test_idx = (
    (
        pd.Series(list(map(lambda x: user_features_mapping[x], df_test["userId"])))
        + pd.Series(list(map(lambda x: movie_features_mapping[x], df_test["movieId"])))
    )
    .apply(lambda x: mmh3.hash(x) % cross_feats_dim)
    .values
)
cross_test = torch.zeros(df_test.shape[0], cross_feats_dim)
cross_test[torch.arange(cross_test.shape[0]), test_idx] = 1


# cross features for val
val_idx = (
    (
        pd.Series(list(map(lambda x: user_features_mapping[x], df_val["userId"])))
        + pd.Series(list(map(lambda x: movie_features_mapping[x], df_val["movieId"])))
    )
    .apply(lambda x: mmh3.hash(x) % cross_feats_dim)
    .values
)
cross_val = torch.zeros(df_val.shape[0], cross_feats_dim)
cross_val[torch.arange(cross_val.shape[0]), val_idx] = 1

# %% [markdown]
# ## Wide-and-Deep Best

# %%
seed_everything(RANDOM_STATE)
train_loader = DataLoader(
    trainDatasetWithCrossFeatures(
        df_train,
        df_movies["movieId"].nunique(),
        user_features_mapping,
        movie_features_mapping,
        hash_bucket_size=cross_feats_dim,
    ),
    batch_size=2048,
    shuffle=True,
)
val_loader = DataLoader(
    TensorDataset(
        torch.tensor(df_val["userId"]), torch.tensor(df_val["movieId"]), cross_val
    ),
    batch_size=4096,
    shuffle=False,
)
test_loader = DataLoader(
    TensorDataset(
        torch.tensor(df_test["userId"]), torch.tensor(df_test["movieId"]), cross_test
    ),
    batch_size=4096,
    shuffle=False,
)
num_users = df_users["userId"].nunique()
num_items = df_movies["movieId"].nunique()
# Out:
#   0%|          | 0/994175 [00:00<?, ?it/s]
# IOStream.flush timed out
# IOStream.flush timed out
#   0%|          | 0/4970875 [00:00<?, ?it/s]

# %% [markdown]
# **Best hyper parametres combination after tuning:**
#
# Trial 4 finished with value: 0.6230684518814087 and parameters: {
#
# 'n_mlp_layers': 9,
#
# 'mlp_layers_dim': 400.0,
#
# 'mlp_kwargs_dropout': False,
#
# 'mlp_kwargs_batchnorm': False,
#
# 'mlp_kwargs_dropout_rate': 0.10651146716504352,
#
# 'lr': 0.0027311465340585516,
#
# 'n_epochs': 7.0
#
# }

# %%
seed_everything(RANDOM_STATE)
wd = wideAndDeep(
    num_users,
    num_items,
    cross_feats_dim=cross_feats_dim,
    n_mlp_layers=9,
    mlp_layers_dim=400,
    mlp_kwargs={
        "activation": True,
        "dropout": False,
        "batchnorm": False,
        "dropout_rate": 0.11,
    },
)
display(wd)
# Out:
# wideAndDeep(
#   (user_embedding): Embedding(6041, 200)
#   (item_embedding): Embedding(3883, 200)
#   (mlp): Sequential(
#     (MLP_layer_0): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_1): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_2): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_3): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_4): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_5): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_6): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_7): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#     (MLP_layer_8): MLP(
#       (block): Sequential(
#         (Linear): Linear(in_features=400, out_features=400, bias=True)
#         (Activation): ReLU()
#       )
#     )
#   )
#   (cross): MLP(
#     (block): Sequential(
#       (Linear): Linear(in_features=30, out_features=400, bias=True)
#     )
#   )
#   (final): MLP(
#     (block): Sequential(
#       (Linear): Linear(in_features=800, out_features=1, bias=True)
#     )
#   )
# )

# %%
optimizer = torch.optim.Adam(wd.parameters(), lr=0.0027)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.8)
criterion = torch.nn.BCELoss()
n_epochs = 7
device = "cpu"

# %%
# %%time
train(
    wd,
    train_loader,
    optimizer,
    scheduler,
    criterion,
    n_epochs,
    val_loader=val_loader,
    df_val=df_val,
    cos_dist=cos_dist,
    popularity=popularity,
    verbose=True,
)
# Out:
# Epochs:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 0
# Train loss: 0.35754
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.5798),
#  'NDCG @ 15': tensor(0.2867),
#  'Diversity (ILD)': tensor(0.1418),
#  'Novelty (EPC)': tensor(0.6940)}
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 1
# Train loss: 0.32558
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.6443),
#  'NDCG @ 15': tensor(0.3111),
#  'Diversity (ILD)': tensor(0.1305),
#  'Novelty (EPC)': tensor(0.7245)}
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 2
# Train loss: 0.30056
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.6625),
#  'NDCG @ 15': tensor(0.3270),
#  'Diversity (ILD)': tensor(0.1254),
#  'Novelty (EPC)': tensor(0.7396)}
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 3
# Train loss: 0.28165
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.6642),
#  'NDCG @ 15': tensor(0.3356),
#  'Diversity (ILD)': tensor(0.1205),
#  'Novelty (EPC)': tensor(0.7521)}
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 4
# Train loss: 0.26622
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.6807),
#  'NDCG @ 15': tensor(0.3456),
#  'Diversity (ILD)': tensor(0.1181),
#  'Novelty (EPC)': tensor(0.7575)}
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 5
# Train loss: 0.25339
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.6956),
#  'NDCG @ 15': tensor(0.3498),
#  'Diversity (ILD)': tensor(0.1150),
#  'Novelty (EPC)': tensor(0.7644)}
#   0%|          | 0/2428 [00:00<?, ?batch/s]
# Epoch: 6
# Train loss: 0.2423
# Inference:   0%|          | 0/30 [00:00<?, ?batch/s]
# {'Hit rate @ 15': tensor(0.6898),
#  'NDCG @ 15': tensor(0.3470),
#  'Diversity (ILD)': tensor(0.1135),
#  'Novelty (EPC)': tensor(0.7686)}
# CPU times: user 43min 31s, sys: 1h 52min 1s, total: 2h 35min 32s
# Wall time: 17min 12s

# %%
df_test["pred"] = predict(wd, test_loader, verbose=False).numpy()
pred, target, pred_items = split_test_df(df_test, "userId", "movieId", "pred", "action")
reccomendation_report(pred, target, pred_items, cos_dist, popularity, k=15)
# Out:
# {'Hit rate @ 15': tensor(0.7121),
#  'NDCG @ 15': tensor(0.3656),
#  'Diversity (ILD)': tensor(0.1132),
#  'Novelty (EPC)': tensor(0.7665)}

# %% [markdown]
# ## Test user recommendations

# %%
df_test_user = add_not_watched_movies(new_user_id, df_test, df_train, df_movies)

# cross features for test user
test_idx = (
    (
        pd.Series(list(map(lambda x: user_features_mapping[x], df_test_user["userId"])))
        + pd.Series(
            list(map(lambda x: movie_features_mapping[x], df_test_user["movieId"]))
        )
    )
    .apply(lambda x: mmh3.hash(x) % cross_feats_dim)
    .values
)
cross_test_user = torch.zeros(df_test_user.shape[0], cross_feats_dim)
cross_test_user[torch.arange(cross_test_user.shape[0]), test_idx] = 1

test_user_loader = DataLoader(
    TensorDataset(
        torch.tensor(df_test_user["userId"]),
        torch.tensor(df_test_user["movieId"]),
        cross_test_user,
    ),
    batch_size=4096,
    shuffle=False,
)

# %%
df_test_user["pred"] = predict(wd, test_user_loader, verbose=False).numpy()
display(create_test_user_display_df(df_test_user, df_movies, "pred"))
# Out:
#      userId  movieId                                               name  \
# 0      6040       10                     American President, The (1995)
# 1      6040     1720                         Wedding Singer, The (1998)
# 2      6040     2252                               Pleasantville (1998)
# 3      6040      582                                  Home Alone (1990)
# 4      6040      591                        Beauty and the Beast (1991)
# 5      6040      139                               Birdcage, The (1996)
# 6      6040     1854                There's Something About Mary (1998)
# 7      6040     2075                             Sixteen Candles (1984)
# 8      6040      558                    Welcome to the Dollhouse (1995)
# 9      6040      464  Englishman Who Went Up a Hill, But Came Down a...
# 10     6040     2222                         Edward Scissorhands (1990)
# 11     6040     1019                         Alice in Wonderland (1951)
# 12     6040      219                           Circle of Friends (1995)
# 13     6040     1393                                       Evita (1996)
# 14     6040      527                          Secret Garden, The (1993)
# 15     6040     2018                                   Peter Pan (1953)
# 16     6040     2220                                 Player, The (1992)
# 17     6040     2367                          Tea with Mussolini (1999)
# 18     6040     1899                         Breakfast Club, The (1985)
# 19     6040     1078                            Crying Game, The (1992)
# 20     6040     1455                                   Liar Liar (1997)
# 21     6040     1001                                   Pollyanna (1960)
# 22     6040     1171                           Strictly Ballroom (1992)
# 23     6040     3841                                Best in Show (2000)
# 24     6040     3088                               Stuart Little (1999)
# 25     6040     3329                 Muppets Take Manhattan, The (1984)
# 26     6040      682                           Mrs. Winterbourne (1996)
# 27     6040     3443                                Return to Me (2000)
# 28     6040     1270                      Some Kind of Wonderful (1987)
# 29     6040     2472                            Cruel Intentions (1999)
# 30     6040       63                               Two if by Sea (1996)
# 31     6040      367                                  Paper, The (1994)
# 32     6040     2325                        Prince of Egypt, The (1998)
# 33     6040     3467                           Keeping the Faith (2000)
# 34     6040     1499           Shall We Dance? (Shall We Dansu?) (1996)
# 35     6040     2935                               Bachelor, The (1999)
# 36     6040     1457                                      Selena (1997)
# 37     6040     1336                                       Shine (1996)
# 38     6040     3328                     Great Muppet Caper, The (1981)
# 39     6040     3480                              Guys and Dolls (1955)
# 40     6040     2588              Rocky Horror Picture Show, The (1975)
# 41     6040      102                               Happy Gilmore (1996)
# 42     6040      368                               Reality Bites (1994)
# 43     6040     1017                               Pete's Dragon (1977)
# 44     6040     2631        South Park: Bigger, Longer and Uncut (1999)
# 45     6040     2874                                   Indochine (1992)
# 46     6040     3076                       Cradle Will Rock, The (1999)
# 47     6040     3525                                Center Stage (2000)
# 48     6040      719                           Cold Comfort Farm (1995)
# 49     6040     1028                              Secrets & Lies (1996)
# 50     6040     1656                           Good Will Hunting (1997)
# 51     6040     1211                                  Annie Hall (1977)
# 52     6040      523                            Schindler's List (1993)
# 53     6040     1227                               Graduate, The (1967)
# 54     6040      576                            Princess Caraboo (1994)
# 55     6040     1377                             In Love and War (1996)
# 56     6040     2287                                   Celebrity (1998)
# 57     6040     1684                                   Afterglow (1997)
# 58     6040     3529                                      Hamlet (2000)
# 59     6040     1663     Midnight in the Garden of Good and Evil (1997)
# 60     6040     1670                        Sweet Hereafter, The (1997)
# 61     6040     2023                        Return of Jafar, The (1993)
# 62     6040     1010        Winnie the Pooh and the Blustery Day (1968)
# 63     6040     1608                     FairyTale: A True Story (1997)
# 64     6040      484                                M. Butterfly (1993)
# 65     6040      274                      Miracle on 34th Street (1994)
# 66     6040     1602                           House of Yes, The (1997)
# 67     6040     1743                                      Paulie (1998)
# 68     6040      269                 Madness of King George, The (1994)
# 69     6040     3181                                       Alive (1993)
# 70     6040     3049                                 Tumbleweeds (1999)
# 71     6040     1259                              Night on Earth (1991)
# 72     6040      665     Mystery Science Theater 3000: The Movie (1996)
# 73     6040     1647                                Apostle, The (1997)
# 74     6040      443                                  Favor, The (1994)
# 75     6040     2815                                    Dog Park (1998)
# 76     6040     2064                   Adventures in Babysitting (1987)
# 77     6040       54                                     Georgia (1995)
# 78     6040     3715                                    Kid, The (2000)
# 79     6040     1551                                     Air Bud (1997)
# 80     6040      510                                    Ref, The (1994)
# 81     6040     3414                      Road to El Dorado, The (2000)
# 82     6040      743                        Month by the Lake, A (1995)
# 83     6040     2651                            Inspector Gadget (1999)
# 84     6040      657               Kids in the Hall: Brain Candy (1996)
# 85     6040      450                                   Firm, The (1993)
# 86     6040     2505                         Out-of-Towners, The (1999)
# 87     6040     3495         Flintstones in Viva Rock Vegas, The (2000)
# 88     6040     2759                             Dudley Do-Right (1999)
# 89     6040     2820                             Mystery, Alaska (1999)
# 90     6040     2401                            Crocodile Dundee (1986)
# 91     6040     1734               Love and Death on Long Island (1997)
# 92     6040       99                               Bottle Rocket (1996)
# 93     6040     1968                                  Candleshoe (1977)
# 94     6040      437                          Dazed and Confused (1993)
# 95     6040     3754                          Autumn in New York (2000)
# 96     6040      448                                Widows' Peak (1994)
# 97     6040     2728                                         Big (1988)
# 98     6040     2877                                       Help! (1965)
# 99     6040      573                                       Andre (1994)
# 100    6040     1770                                    My Giant (1998)
#
#                                       genre      pred
# 0                      Comedy|Drama|Romance  0.980934
# 1                            Comedy|Romance  0.954767
# 2                                    Comedy  0.923652
# 3                         Children's|Comedy  0.886759
# 4              Animation|Children's|Musical  0.878612
# 5                                    Comedy  0.861535
# 6                                    Comedy  0.853699
# 7                                    Comedy  0.842035
# 8                              Comedy|Drama  0.836910
# 9                            Comedy|Romance  0.831498
# 10                            Drama|Romance  0.813150
# 11             Animation|Children's|Musical  0.805988
# 12                            Drama|Romance  0.802343
# 13                            Drama|Musical  0.786124
# 14                         Children's|Drama  0.785228
# 15     Animation|Children's|Fantasy|Musical  0.779349
# 16                             Comedy|Drama  0.743845
# 17                                   Comedy  0.733672
# 18                             Comedy|Drama  0.694946
# 19                        Drama|Romance|War  0.682086
# 20                                   Comedy  0.677117
# 21                  Children's|Comedy|Drama  0.674299
# 22                           Comedy|Romance  0.649393
# 23                                   Comedy  0.605691
# 24                        Children's|Comedy  0.597710
# 25                        Children's|Comedy  0.592083
# 26                           Comedy|Romance  0.584405
# 27                            Drama|Romance  0.574029
# 28                            Drama|Romance  0.557102
# 29                                    Drama  0.553212
# 30                           Comedy|Romance  0.543416
# 31                             Comedy|Drama  0.542494
# 32                        Animation|Musical  0.542217
# 33                           Comedy|Romance  0.538417
# 34                                   Comedy  0.535901
# 35                           Comedy|Romance  0.531088
# 36                            Drama|Musical  0.526206
# 37                            Drama|Romance  0.521854
# 38                        Children's|Comedy  0.516791
# 39                                  Musical  0.455935
# 40             Comedy|Horror|Musical|Sci-Fi  0.440798
# 41                                   Comedy  0.431229
# 42                             Comedy|Drama  0.427959
# 43   Adventure|Animation|Children's|Musical  0.424300
# 44                         Animation|Comedy  0.389306
# 45                            Drama|Romance  0.373739
# 46                                    Drama  0.369886
# 47                                    Drama  0.347558
# 48                                   Comedy  0.338734
# 49                                    Drama  0.336240
# 50                                    Drama  0.330834
# 51                           Comedy|Romance  0.311383
# 52                                Drama|War  0.309856
# 53                            Drama|Romance  0.297278
# 54                                    Drama  0.291523
# 55                              Romance|War  0.283877
# 56                                   Comedy  0.280112
# 57                            Drama|Romance  0.275408
# 58                                    Drama  0.273928
# 59               Comedy|Crime|Drama|Mystery  0.269109
# 60                                    Drama  0.265606
# 61             Animation|Children's|Musical  0.253095
# 62                     Animation|Children's  0.251729
# 63                 Children's|Drama|Fantasy  0.240694
# 64                                    Drama  0.240322
# 65                                    Drama  0.237894
# 66                    Comedy|Drama|Thriller  0.237648
# 67              Adventure|Children's|Comedy  0.234100
# 68                                    Drama  0.231880
# 69                                    Drama  0.222768
# 70                                    Drama  0.217589
# 71                             Comedy|Drama  0.216457
# 72                            Comedy|Sci-Fi  0.210160
# 73                                    Drama  0.199626
# 74                           Comedy|Romance  0.198345
# 75                           Comedy|Romance  0.196572
# 76                         Adventure|Comedy  0.191760
# 77                                    Drama  0.190972
# 78                                   Comedy  0.190405
# 79                        Children's|Comedy  0.188355
# 80                                   Comedy  0.188242
# 81                     Animation|Children's  0.187264
# 82                             Comedy|Drama  0.186512
# 83       Action|Adventure|Children's|Comedy  0.186145
# 84                                   Comedy  0.185990
# 85                           Drama|Thriller  0.182156
# 86                                   Comedy  0.177869
# 87                        Children's|Comedy  0.176786
# 88                        Children's|Comedy  0.175727
# 89                                   Comedy  0.174645
# 90                         Adventure|Comedy  0.168599
# 91                             Comedy|Drama  0.164393
# 92                                   Comedy  0.164205
# 93              Adventure|Children's|Comedy  0.163423
# 94                                   Comedy  0.162221
# 95                            Drama|Romance  0.154397
# 96                                    Drama  0.153741
# 97                           Comedy|Fantasy  0.152252
# 98                           Comedy|Musical  0.151897
# 99                     Adventure|Children's  0.136610
# 100                                  Comedy  0.135105
